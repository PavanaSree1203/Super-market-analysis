# %%
#Importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Getting the details of files in the given directory path
import os
for dirname, _, filenames in os.walk("C:/Users/Pavana Sree/Downloads"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:/Users/Pavana Sree/Downloads\.Rhistory
# C:/Users/Pavana Sree/Downloads\1-cffc3309-d082-4c5f-b01a-5106db4b6cb1 (1).pdf
# C:/Users/Pavana Sree/Downloads\1142pm_1.EPRA JOURNALS 14814.pdf
# C:/Users/Pavana Sree/Downloads\2DSTCS 2023 .csv
# C:/Users/Pavana Sree/Downloads\4th sem - DS - Spark (1).docx
# C:/Users/Pavana Sree/Downloads\4th sem - DS - Spark (2).docx
# C:/Users/Pavana Sree/Downloads\4th sem - DS - Spark (3).docx
# C:/Users/Pavana Sree/Downloads\4th sem - DS - Spark.docx
# C:/Users/Pavana Sree/Downloads\4th sem - DS - Tableau (1).docx
# C:/Users/Pavana Sree/Downloads\Aditya_Degree_Colleges_C_Coding_Test-1_report.xlsx
# C:/Users/Pavana Sree/Downloads\ADITYA_Degree_Python_Coding_Test-2_Results.xlsx
# C:/Users/Pavana Sree/Downloads\Adobe Scan 12-Mar-2024.pdf
# C:/Users/Pavana Sree/Downloads\Adobe Scan 13-Mar-2024.pdf
# C:/Users/Pavana Sree/Downloads\Adobe Scan 18 Apr 2024 (1).pdf
# C:/Users/Pavana Sree/Downloads\Adobe Scan 31-Jan-2024.pdf
# C:/Users/Pavana Sree/Downloads\AI&ML updated notes.pdf
# C:/Users/Pavana Sree/Downloads\AI.png
# C:/Users/Pavana Sree/Downloads\ALL_GATES_499_WF (1).docx
# C:/Users/Pavana Sree/Downloads\ALL_GATES_499_WF (2).docx
# C:/Users/Pavana Sree/Downloads\ALL_GATES_499_WF.docx
# C:/Users/Pavana Sree/Downloads\Anaconda3-2022.10-Windows-x86_64.exe
# C:/Users/Pavana Sree/Downloads\annual-balance-sheets-2007-2021-provisional.csv
# C:/Users/Pavana Sree/Downloads\appli.jpg
# C:/Users/Pavana Sree/Downloads\archive (1).zip
# C:/Users/Pavana Sree/Downloads\archive (2).zip
# C:/Users/Pavana Sree/Downloads\archive.zip
# C:/Users/Pavana Sree/Downloads\AS 3 model pdf  (1).pdf
# C:/Users/Pavana Sree/Downloads\AS 3 model pdf .pdf
# C:/Users/Pavana Sree/Downloads\AS model pdf.pdf
# C:/Users/Pavana Sree/Downloads\aws telugu letter (1).pdf
# C:/Users/Pavana Sree/Downloads\aws telugu letter.pdf
# C:/Users/Pavana Sree/Downloads\BCA & B.SC (II YEAR).xlsx
# C:/Users/Pavana Sree/Downloads\BCD TO EXCESS 3 CODE 493 (1).docx
# C:/Users/Pavana Sree/Downloads\BCD TO EXCESS 3 CODE 493.docx
# C:/Users/Pavana Sree/Downloads\BINARY TO GRAY CODE_493 - Copy (1).docx
# C:/Users/Pavana Sree/Downloads\BINARY TO GRAY CODE_493 - Copy (2).docx
# C:/Users/Pavana Sree/Downloads\BINARY TO GRAY CODE_493 - Copy.docx
# C:/Users/Pavana Sree/Downloads\bloodshed-dev-c-5.11-installer.exe
# C:/Users/Pavana Sree/Downloads\trail project (1).R
# C:/Users/Pavana Sree/Downloads\Transcation Details.xlsx
# C:/Users/Pavana Sree/Downloads\Turbo.C.3.2.zip
# C:/Users/Pavana Sree/Downloads\TurboC++ for Windows 7_v3.7.8.9major_release (1).exe
# C:/Users/Pavana Sree/Downloads\TurboC++ for Windows 7_v3.7.8.9major_release.exe
# C:/Users/Pavana Sree/Downloads\ULEARN BOOK.pdf
# C:/Users/Pavana Sree/Downloads\ulearn_internship_book (1).pdf
# C:/Users/Pavana Sree/Downloads\ulearn_internship_book.pdf
# C:/Users/Pavana Sree/Downloads\Unconfirmed 183370.crdownload
# C:/Users/Pavana Sree/Downloads\unit 1  observation  applied statistics .pdf
# C:/Users/Pavana Sree/Downloads\unit 2 observation applied statistics .pdf
# C:/Users/Pavana Sree/Downloads\Unit 4 - DS - 1st year.pdf
# C:/Users/Pavana Sree/Downloads\Unit 5 - DS - 1st year.docx
# C:/Users/Pavana Sree/Downloads\UTIITSL_ePAN_A093261694_14052024_214534.pdf
# C:/Users/Pavana Sree/Downloads\VHDL FOR AND GATE-493 (1).pdf
# C:/Users/Pavana Sree/Downloads\VHDL FOR AND GATE-493 (2).pdf
# C:/Users/Pavana Sree/Downloads\VHDL FOR AND GATE-493.pdf
# C:/Users/Pavana Sree/Downloads\WA_Fn-UseC_-Telco-Customer-Churn (1).csv
# C:/Users/Pavana Sree/Downloads\webex.exe
# C:/Users/Pavana Sree/Downloads\WhatsApp Image 2023-08-20 at 1.57.17 PM.jpeg
# C:/Users/Pavana Sree/Downloads\WhatsApp Image 2024-05-11 at 15.49.45.jpeg
# C:/Users/Pavana Sree/Downloads\WhatsApp Image 2024-05-11 at 16.23.44.jpeg
# C:/Users/Pavana Sree/Downloads\WavesAudio.MaxxAudioProforDell2021_fh4rh281wavaa!App\desktop.ini

# %%
#Reading data into a variable
data = pd.read_csv('C:/Users/Pavana Sree/Downloads/supermarket.csv')

# %%
#Displaying 1st 5 rows
data.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
#Displaying the count of rows & columns
data.shape
# Out:
# (1000, 17)

# %%
#Details of each column 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
#outputing the statistical values of the data
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.924875     5.50000
# 50%               4.761905e+00     12.088000     7.00000
# 75%               4.761905e+00     22.445250     8.50000
# max               4.761905e+00     49.650000    10.00000

# %%
#Determining the null values
data.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#determining the duplicate
data.duplicated().sum()
# Out:
# 0

# %%
#column names
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
#Determining the data type of column
data.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
#creating a function for displaying a piechart for the given data
def display_pie_chart(values, labels, title, chart_type = 'pie'):
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot()
    if chart_type == 'doughnat':
        explode = np.full(len(labels), 0.05)
        ax.pie(values, labels=labels, autopct='%1.1f%%', startangle=90, explode = explode, pctdistance=0.85)
        centre_circle = plt.Circle((0, 0), 0.70, fc='white')
        fig = plt.gcf()
        fig.gca().add_artist(centre_circle)
    else:
        ax.pie(values, labels=labels, autopct='%1.1f%%', startangle=90)
    ax.axis('equal')  
    ax.set_title(title)
    
    
    plt.savefig(f'{labels[0]}', bbox_inches='tight')
    plt.show()

# %%
#grouping the columns
def group_by_column(df, col, function):
    grouped_df = df.groupby(col).agg(function).reset_index()
    grouped_df = grouped_df.set_index(col)

    return grouped_df

# %%
#generating piechart differentiated by gender
gender_and_total = data[['Gender', 'Total']]

grouped_by_gender_df = group_by_column(gender_and_total, 'Gender', 'sum')

print(grouped_by_gender_df)

labels = grouped_by_gender_df.index
values = grouped_by_gender_df['Total']

display_pie_chart(values, labels, 'Total Sales by Gender')
# Out:
#              Total
# Gender
# Female  167882.925
# Male    155083.824

# %%
#creating a doughnat piechart based on the customer type
group_by_type = data[['Customer type', 'Total']]

group_by_type_df = group_by_column(group_by_type, 'Customer type', 'sum')

print(group_by_type_df)

labels = group_by_type_df.index
values = group_by_type_df['Total']

display_pie_chart(values, labels, 'Total Sales by Customer type', chart_type = 'doughnat')
# Out:
#                     Total
# Customer type
# Member         164223.444
# Normal         158743.305

# %%
#generating 5 rows of grouped data formed
group = data.groupby(['Product line', 'Gender']).size().reset_index()
group.columns = ['Product line', 'Gender', 'Count']

group.head(5)
# Out:
#              Product line  Gender  Count
# 0  Electronic accessories  Female     84
# 1  Electronic accessories    Male     86
# 2     Fashion accessories  Female     96
# 3     Fashion accessories    Male     82
# 4      Food and beverages  Female     90

# %%
#creating barplot
plt.figure(figsize=(15, 10))


sns.barplot(data=group, x="Product line", y="Count", hue="Gender")
plt.title('Count of Product Line by Gender')
plt.xlabel('Product Line')
plt.ylabel('Count')
plt.savefig('count_by_gender')
plt.show()

# %%
#identifying the cities
data.City.unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
#identifying the branches & most selling branch
branches_sales = data.groupby('Branch')['Total'].sum()

for branch, sales in branches_sales.items():
    print(f'Branch {branch} : {sales}')
    
print('-' * 50)

most_selling_branch = branches_sales.idxmax()

print(f'The most selling branch is {most_selling_branch}')
# Out:
# Branch A : 106200.3705
# Branch B : 106197.672
# Branch C : 110568.7065
# --------------------------------------------------
# The most selling branch is C

# %%
#creating barchat of total sales in each city
plt.figure(figsize=(10, 6))

branches_sales.plot(kind='bar', color='skyblue')
plt.title('Total Sales by City')
plt.xlabel('City')
plt.ylabel('Total Sales')
plt.show()

# %%
#creating a piechart of average customers differentiated by cities
customer_rate = data.groupby('City')['Rating'].mean()

cities = customer_rate.index
rates = customer_rate

print(customer_rate)

display_pie_chart(rates, cities, 'Avarage Customers Rate by City')
# Out:
# City
# Mandalay     6.818072
# Naypyitaw    7.072866
# Yangon       7.027059
# Name: Rating, dtype: float64

# %%
#Determining the highest selling product
product_sales = data.groupby('Product line')['Quantity'].sum()

highest_selling_product = product_sales.idxmax()

print("Highest selling product:", highest_selling_product)
# Out:
# Highest selling product: Electronic accessories

# %%
#Histogram on sales of each product
plt.figure(figsize=(12, 8))

product_sales.plot(kind='bar',color="pink")
plt.title('Product Sales by Quantity')
plt.xlabel('Product Category',  rotation=0)
plt.ylabel('Quantity')
plt.show()

# %%
#creating a doughnat piechart
grouped_products = data.groupby('Product line')['gross income'].sum()

products = grouped_products.index
income = grouped_products

display_pie_chart(income, products, '', chart_type='doughnat')

# %%
#creating a dataframe
dates = pd.DataFrame()

# Convert Date values in dataset to pd.datetime object
dates['Date'] = pd.to_datetime(data['Date'])

# separate year value form datetime object
dates['Year'] = dates['Date'].dt.year

# separate month value form datetime object
dates['Month'] = dates['Date'].dt.month

# separate day value form datetime object
dates['Day'] = dates['Date'].dt.day

# Get Total column values from the original datafram 
dates['Total'] = data['Total']

dates
# Out:
#           Date  Year  Month  Day      Total
# 0   2019-01-05  2019      1    5   548.9715
# 1   2019-03-08  2019      3    8    80.2200
# 2   2019-03-03  2019      3    3   340.5255
# 3   2019-01-27  2019      1   27   489.0480
# 4   2019-02-08  2019      2    8   634.3785
# ..         ...   ...    ...  ...        ...
# 995 2019-01-29  2019      1   29    42.3675
# 996 2019-03-02  2019      3    2  1022.4900
# 997 2019-02-09  2019      2    9    33.4320
# 998 2019-02-22  2019      2   22    69.1110
# 999 2019-02-18  2019      2   18   649.2990
#
# [1000 rows x 5 columns]

# %%
#determining the sales per month
monthly_sales = dates.groupby(['Month', 'Day'])['Total'].sum()

monthly_sales
# Out:
# Month  Day
# 1      1      4745.1810
#        2      1945.5030
#        3      2078.1285
#        4      1623.6885
#        5      3536.6835
#                 ...
# 3      26     1962.5130
#        27     2902.8195
#        28     2229.4020
#        29     4023.2430
#        30     4487.0595
# Name: Total, Length: 89, dtype: float64

# %%
#visualization for each month of sales
for month in range(1, 4):
    plt.figure(figsize=(8, 6))
    month_data = monthly_sales.loc[month]
    plt.plot(month_data.index.get_level_values('Day'), month_data.values)
    plt.title(f'Monthly Sales for Month {month}')
    plt.xlabel('Day')
    plt.ylabel('Total Sales')
    plt.grid(True)
    plt.savefig(f'{month}')
    plt.show()
